# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
skew = pd.read_csv(r'csv/peakskew_map.csv').values
width = pd.read_csv(r'csv/peakwidth_map.csv').values

# %%
skew.shape
skew = np.ravel(skew)
width = np.ravel(width)
skew.shape
width.shape
# Out:
# (3721,)

# %%
df = pd.DataFrame({'skew':skew, 'width':width})
plt.scatter(x=skew,y=width)

# %%
df['n'] = range(3721)
df.head()
# Out:
#        skew      width  n
# 0  5.837524  54.133423  0
# 1  4.233093  52.528992  1
# 2  1.019226  51.463684  2
# 3  2.093933  50.391541  3
# 4  1.021545  50.391541  4

# %%
new_df = df.loc[(df['skew']**2+(df['width']-60)**2<= 150)]
plt.scatter(x=new_df['skew'],y=new_df['width'])
